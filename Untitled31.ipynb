# %%
# import the pandas library
import pandas as pd
data = {'Name':['Ashika', 'Tanu', 'Ashwin', 'Mohit', 'Sourabh'],
                 'Age': [24, 23, 22, 19, 10]}
data
# Out:
# {'Name': ['Ashika', 'Tanu', 'Ashwin', 'Mohit', 'Sourabh'],
#  'Age': [24, 23, 22, 19, 10]}

# %%
# Calling the pandas data frame method by passing the dictionary (data) as a parameter
df = pd.DataFrame(data)
df

# %%
df
# Out:
#       Name  Age
# 0   Ashika   24
# 1     Tanu   23
# 2   Ashwin   22
# 3    Mohit   19
# 4  Sourabh   10

# %%
df[['Age']]
# Out:
#    Age
# 0   24
# 1   23
# 2   22
# 3   19
# 4   10

# %%
df[['Name']]
# Out:
#       Name
# 0   Ashika
# 1     Tanu
# 2   Ashwin
# 3    Mohit
# 4  Sourabh

# %%
print(type(df[['Name']]))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
row = df.loc[4]

# %%
row
# Out:
# Name    Sourabh
# Age          10
# Name: 4, dtype: object

# %%
               del df['Age']

# %%
df
# Out:
#       Name
# 0   Ashika
# 1     Tanu
# 2   Ashwin
# 3    Mohit
# 4  Sourabh

# %%
import pandas as pd
data = {'Name':['Ashika', 'Tanu', 'Ashwin', 'Mohit', 'Sourabh'],
        'Age': [24, 23, 22, 19, 10]}
data
# Out:
# {'Name': ['Ashika', 'Tanu', 'Ashwin', 'Mohit', 'Sourabh'],
#  'Age': [24, 23, 22, 19, 10]}

# %%
df = pd.DataFrame(data)
df.insert(2, 'name', df['Name'])

# %%
df
# Out:
#       Name  Age     name
# 0   Ashika   24   Ashika
# 1     Tanu   23     Tanu
# 2   Ashwin   22   Ashwin
# 3    Mohit   19    Mohit
# 4  Sourabh   10  Sourabh
